# %%
from datasets import load_dataset

# Load full dataset
dataset = load_dataset("EPFL-ECEO/coralscapes")

# %%
dataset = load_from_disk(r"C:\Users\anair26\OneDrive - Eastside Preparatory School\coral-health-classification\coralscapesdata")
# Out:
# Saving the dataset (9/9 shards): 100%|██████████| 1517/1517 [00:25<00:00, 60.30 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 166/166 [00:01<00:00, 111.55 examples/s]
# Saving the dataset (3/3 shards): 100%|██████████| 392/392 [00:07<00:00, 49.67 examples/s]
